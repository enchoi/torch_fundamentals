# %% [markdown]
# # Le RNN avec Pytorch

# %% [markdown]
# Dans ce notebook, vous allez découvrir comment utiliser le RNN avec Pytorch pour résoudre un problème de série temporelle.
#
# Le but sera de prédire la température de Delhi au cours du temps.
#
# Vous pouvez retrouver le jeu de donneés sur [Kaggle](https://www.kaggle.com/datasets/sumanthvrao/daily-climate-time-series-data).

# %% [markdown]
# # Importation des packages

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import torch as torch
from torch.utils.data import Dataset
from torchsummary import summary

import matplotlib.pyplot as plt

# %% [markdown]
# # Importation des données

# %% [markdown]
# J'ai hébergé les données sur mon compte Google Drive pour vous permettre de gagner du temps et de ne pas devoir les charger sur votre session Google Colab.
#
# Vous avez seulement à ajouter un raccourci de mon Drive au votre, puis à lier votre compte Google Colab à votre compte Google Drive pour avoir accès aux données.
#
# Les données ne seront en aucun cas sur votre Drive, seul un raccourci où se situe les données sera présent.

# %% [markdown]
# ### Lier les données à votre Drive

# %% [markdown]
# Lien du drive:
#
# https://drive.google.com/drive/folders/1oYQazCKVZZiCPVP6z9R37NHtXy-faBhy?usp=sharing

# %% [markdown]
# **Cliquez** sur le lien.
#
# **Cliquez** droit sur le dossier *delhi_climate* comme sur la photo ci-dessous.

# %% [markdown]
# ![ajouter au drive delhi.png](data:image/png;base64,...)

# %% [markdown]
# **Cliquez** sur l'option *Ajouter un raccourci dans Drive*.

# %% [markdown]
# ## Lier votre compte Google Colab à votre Drive

# %% [markdown]
# **Exécutez** la cellule ci-dessous pour lier votre compte Google Drive à votre session Google Colab.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/MyDrive/delhi_climate/DailyDelhiClimateTrain.csv')
train.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
test = pd.read_csv('/content/drive/MyDrive/delhi_climate/DailyDelhiClimateTest.csv')
test.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1  2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2  2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3  2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4  2017-01-05  18.388889  74.944444    3.300000   1014.333333

# %% [markdown]
# # Analyse du jeu de données

# %% [markdown]
# ##Statistiques descriptives

# %%
train.describe()
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333

# %% [markdown]
# On peut remarquer des outliers dans la mesure de la pression pour le jeu d'entraînement.

# %%
test.describe()
# Out:
#          meantemp    humidity  wind_speed  meanpressure
# count  114.000000  114.000000  114.000000    114.000000
# mean    21.713079   56.258362    8.143924   1004.035090
# std      6.360072   19.068083    3.588049     89.474692
# min     11.000000   17.750000    1.387500     59.000000
# 25%     16.437198   39.625000    5.563542   1007.437500
# 50%     19.875000   57.750000    8.069444   1012.739316
# 75%     27.705357   71.902778   10.068750   1016.739583
# max     34.500000   95.833333   19.314286   1022.809524

# %% [markdown]
# ## Données manquantes

# %% [markdown]
# Checkez s'il y a des valeurs manquantes.

# %%
train.isna().sum()
# Out:
# date            0
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %%
test.isna().sum()
# Out:
# date            0
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %% [markdown]
# Aucune données manquantes.

# %% [markdown]
# ## Gestion des outliers

# %%
train['meanpressure'].sort_values()
# Out:
# 1323      -3.041667
# 1427      12.045455
# 1309     310.437500
# 1321     633.900000
# 1255     938.066667
#            ...
# 717     1022.125000
# 383     1023.000000
# 1416    1350.296296
# 1362    1352.615385
# 1182    7679.333333
# Name: meanpressure, Length: 1462, dtype: float64

# %% [markdown]
# Si une valeur est plus grande que la moyenne plus 1.5 fois l'écart type on remplace cette valeur par la valeur moyenne plus 1.5 fois l'écart type.

# %%
train['meanpressure'] = np.where(train['meanpressure']>train['meanpressure'].median()+train['meanpressure'].std()*1.5,
                                 train['meanpressure'].median()+train['meanpressure'].std()*1.5,
                                 train['meanpressure'])

# %% [markdown]
# Si une valeur est plus petite que la moyenne moins 1.5 fois l'écart type on remplace cette valeur par la valeur moyenne moins 1.5 fois l'écart type.

# %%
train['meanpressure'] = np.where(train['meanpressure']<train['meanpressure'].median()-train['meanpressure'].std()*1.5,
                                 train['meanpressure'].median()+train['meanpressure'].std()*1.5,
                                 train['meanpressure'])

# %% [markdown]
# ## Visualisation des distributions

# %%
plt.boxplot(x=train['meantemp'])
plt.show()

# %%
plt.boxplot(x=train['humidity'])
plt.show()

# %%
plt.boxplot(x=train['wind_speed'])
plt.show()

# %%
plt.boxplot(x=train['meanpressure'])
plt.show()

# %% [markdown]
# ## Visualisation des séries temporelles

# %%
plt.figure(figsize=(100,80))
fig, axs = plt.subplots(2, 2,figsize=(20,20))
axs[0, 0].plot(train['date'],train['meantemp'])
axs[0, 0].set_title('Mean temp')
axs[0, 1].plot(train['date'],train['humidity'], 'tab:orange')
axs[0, 1].set_title('Humidity')
axs[1, 0].plot(train['date'],train['wind_speed'], 'tab:green')
axs[1, 0].set_title('Wind Speed')
axs[1, 1].plot(train['date'],train['meanpressure'], 'tab:red')
axs[1, 1].set_title('MeanPressure')
plt.show()

# %% [markdown]
# # Pré traitement des données

# %% [markdown]
# Standardisation du jeu d'entraînement.

# %%
scaler_train = StandardScaler()

scaler_train.fit(train.loc[:, ["meantemp", "humidity",
                               "wind_speed", "meanpressure"]])

train_norm = train.copy()

train_norm.loc[:, ["meantemp", "humidity",
                   "wind_speed", "meanpressure"]] = scaler_train.transform(train.loc[:, ["meantemp", "humidity",
                                                                                         "wind_speed", "meanpressure"]])

test_norm = test.copy()

test_norm.loc[:, ["meantemp", "humidity",
                  "wind_speed", "meanpressure"]] = scaler_train.transform(test.loc[:, ["meantemp", "humidity",
                                                                                       "wind_speed", "meanpressure"]])

# %% [markdown]
# # Création du jeu d'entraînement temporel

# %% [markdown]
# Création du jeu de données de série temporelle avec les historiques pour chaque prédiction.

# %%
def create_temporal_dataset(df:pd.DataFrame, target:str, look_back:int=2) -> np.array:
  ''' Create a temporal dataset to predict the y a previous number of terms equal to look_back'''

  # Initialisation of the explaniables variables dataset
  x = np.zeros([df.shape[0]-look_back, look_back, df.shape[1]])
  # Initialisation of the target dataset
  y = np.zeros([df.shape[0]-look_back, 1])

  # For every target value search expainables variables for a number of terms equal to look_back
  for i in range(len(df)-look_back):
      # update x and y
      x[i, :, :] = df.iloc[i:(i+look_back), :]
      y[i, :] = df.loc[(i+look_back), target]
  return x, y

# %% [markdown]
# Pour prédire la prochaine température, on décide de prendre 3 jours d'historiques.

# %%
x_train, y_train = create_temporal_dataset(train_norm.sort_values('date').drop('date', axis=1), 'meantemp', 3)

# %%
x_train.shape
# Out:
# (1459, 3, 4)

# %%
x_test, y_test = create_temporal_dataset(test_norm.sort_values('date').drop('date', axis=1), 'meantemp', 3)

# %%
x_test.shape
# Out:
# (111, 3, 4)

# %% [markdown]
# ## Création du générateur

# %% [markdown]
# Cette fonction permet de créer un générateur Pytorch adapter à la problématique.

# %%
class CustomDataset(Dataset):
    def __init__(self, x_train, y_train):
        self.input = x_train
        self.output = y_train

    def __len__(self):
        return len(self.output)

    def __getitem__(self, idx):
        batch_input = self.input[idx, :, :]
        batch_output = self.output[idx, :]

        return batch_input, batch_output

# %%
x_training = CustomDataset(torch.from_numpy(np.float32(x_train)),
                                 torch.from_numpy(np.float32(y_train)))

# %% [markdown]
# Utilisez la fonction `DataLoader` avec `x_training` et un batch de 32.

# %%
dataloader_train = torch.utils.data.DataLoader(x_training, 32)

# %% [markdown]
# Checkez les dimensions des batchs générés.

# %%
for x, y in dataloader_train:
  print(x.shape)
  print(y.shape)
  break
# Out:
# torch.Size([32, 3, 4])
# torch.Size([32, 1])

# %%
x_testing = CustomDataset(torch.from_numpy(np.float32(x_test)),
                                 torch.from_numpy(np.float32(y_test)))

# %% [markdown]
# Utilisez la fonction `DataLoader` avec `x_training` et un batch de `len(x_testing)`.

# %%
dataloader_test = torch.utils.data.DataLoader(x_testing, len(x_testing))

# %% [markdown]
# Checkez les dimensions des données.

# %%
for x, y in dataloader_test:
  print(x.shape)
  print(y.shape)
  break
# Out:
# torch.Size([1, 3, 4])
# torch.Size([1, 1])

# %% [markdown]
# # Entraînement du modèle

# %% [markdown]
# Fonction d'entraînement.

# %%
def step(model:torch.nn.Sequential,
         opt:torch.optim,
         criterion:torch.nn.modules.loss,
         x_train:torch.Tensor,
         y_train:torch.Tensor)->tuple:
  """
  Executes a single training step for a PyTorch model.
  This function performs a forward pass to compute the model's predictions, calculates
  the loss between predictions and actual target values, computes gradients for each
  model parameter, and updates the parameters using the optimizer.

  Args:
      model (torch.nn.Sequential): The PyTorch model to train.
      optimizer (torch.optim.Optimizer): Optimizer used to update the model's parameters.
      criterion (torch.nn.modules.loss._Loss): Loss function used to compute the error.
      x_train (torch.Tensor): Input training data (features).
      y_train (torch.Tensor): Ground truth labels or target values for the training data.
  Returns:
      tuple: The updated model and the computed loss for the current step.
  """

  # Réinitialisez les gradients d'optimizer à zéro avec la méthode 'zero_grad'
  opt.zero_grad()

  # Calculez les prédiction sur le jeu d'entraînement avec la méthode 'froward'
  prediction = model.forward(x_train)

  # Calculez l'erreur de prédiction avec 'criterion'
  loss = criterion(prediction, y_train)

  # Calculez les gradients avec la méthode 'backward'
  loss.backward()

  # Mettre à jour les paramètres du modèle avec la méthode 'step'
  opt.step()

  return model, loss

# %%
def fit(model, optimizer, criterion, epoch, trainloader, testloader):
    epoch = epoch
    history_train_loss = []
    history_test_loss = []

    for e in range(epoch) :

      train_loss_batch = 0
      test_loss_batch = 0

      for images, labels in trainloader:

        # mise à jour des poids avec la fonction 'step'
        model, train_loss = step(model, optimizer, criterion, images, labels)

        train_loss_batch += train_loss.detach().numpy()


      for images, labels in testloader:

        prediction = model.forward(images)

        test_loss = criterion(prediction, labels)

        test_loss_batch += test_loss.detach().numpy()

      train_loss_batch /= len(trainloader.sampler)
      test_loss_batch /= len(testloader.sampler)

      # Sauvegarde des coûts d'entraînement avec append
      history_train_loss = np.append(history_train_loss, train_loss_batch)
      history_test_loss = np.append(history_test_loss, test_loss_batch)

      print(f'epoch : {e}/{epoch}')
      print('train_loss : '+str(np.squeeze(train_loss_batch))+ ' test_loss : '+str(np.squeeze(test_loss_batch)))
      print('-------------------------------------------------------------------------------------------------')

    return model, history_train_loss, history_test_loss

# %% [markdown]
# ## Initialisation du modèle

# %% [markdown]
# **Utilisez** la fonction `Sequential` pour initialiser le modèle suivant:
# - une couche de RNN avec en utilisant les paramètres de `__init__` et avec batch_first à True.
# - une couche linéaire en utilisant les paramètres `__init__`.
#
#
# Pour la fonction `forward`:
# - D'abord initialiser `h0` qui est un vecteur de 0.
# - Ensuite utiliser `self.rnn`
# - Enfin utiliser `self.fc` en prenant seulement la dernière sortie de `out`.

# %%
# Définir le modèle RNN
class RNNModel(torch.nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(RNNModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        # Couche RNN
        self.rnn = torch.nn.RNN(input_size, self.hidden_size, self.num_layers, batch_first=True)

        # Couche entièrement connectée pour la sortie
        self.fc = torch.nn.Linear(self.hidden_size, output_size)

    def forward(self, x):
        # Initialiser l'état caché avec des zéros
        h0 = torch.zeros(1 * self.num_layers, x.shape[0], self.hidden_size)

        # Passer les données dans la couche RNN
        out, h_n = self.rnn(x, h0)

        # Prendre la dernière sortie de la séquence
        out = self.fc(out[:,-1,:])
        return out

# %% [markdown]
# Utilisez la fonction `RNNModel` pour initialiser le modèle.

# %%
# Définir les dimensions d'entrée et de sortie
input_size = 4
hidden_size = 20
num_layers = 1
output_size = 1

# Initialiser le modèle
model = RNNModel(input_size, hidden_size, num_layers, output_size)

# %% [markdown]
# ## Visualisation du modèle

# %% [markdown]
# **Utilisez** la fonction `summary` pour visualiser votre modèle.

# %%
summary(model, (3, 4), device="cpu")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#                RNN-1  [[-1, 3, 20], [-1, 2, 20]]               0
#             Linear-2                    [-1, 1]              21
# ================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.02
# ----------------------------------------------------------------

# %% [markdown]
# ## Compilation du modèle

# %% [markdown]
# Initialisez `criterion` avec la fonction `L1Loss`.
#
# Initialisez `optimizer` avec `Adam` et un learning rate de 0.001.

# %%
criterion = torch.nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters())

# %% [markdown]
# ## Entraînement du modèle

# %% [markdown]
# Utilisez la fonction `fit` pour entraîner le modèle.

# %%
epoch = 100

# %%
model, history_train_loss, history_test_loss = fit(model, optimizer, criterion, epoch, dataloader_train, dataloader_test)
# Out:
# epoch : 0/100
# train_loss : 0.02229247684957558 test_loss : 0.5869408322347177
# -------------------------------------------------------------------------------------------------
# epoch : 1/100
# train_loss : 0.011652347851976129 test_loss : 0.34198937034821725
# -------------------------------------------------------------------------------------------------
# epoch : 2/100
# train_loss : 0.007637638846352298 test_loss : 0.24935147025295207
# -------------------------------------------------------------------------------------------------
# epoch : 3/100
# train_loss : 0.006756320687660703 test_loss : 0.23531374932677895
# -------------------------------------------------------------------------------------------------
# epoch : 4/100
# train_loss : 0.006486828719164265 test_loss : 0.22482951260633297
# -------------------------------------------------------------------------------------------------
# epoch : 5/100
# train_loss : 0.0062552608238090135 test_loss : 0.21664952728393916
# -------------------------------------------------------------------------------------------------
# epoch : 6/100
# train_loss : 0.006098212409991774 test_loss : 0.2132212035693564
# -------------------------------------------------------------------------------------------------
# epoch : 7/100
# train_loss : 0.005977490346181711 test_loss : 0.20844603007709658
# -------------------------------------------------------------------------------------------------
# epoch : 8/100
# train_loss : 0.005886917176763026 test_loss : 0.20462387981447014
# -------------------------------------------------------------------------------------------------
# epoch : 9/100
# train_loss : 0.005802787401195746 test_loss : 0.20212507630522186
# -------------------------------------------------------------------------------------------------
# epoch : 10/100
# train_loss : 0.005744188452028428 test_loss : 0.19832021165806968
# -------------------------------------------------------------------------------------------------
# epoch : 11/100
# train_loss : 0.005683882206657964 test_loss : 0.19546993996377462
# -------------------------------------------------------------------------------------------------
# epoch : 12/100
# train_loss : 0.005628448610358078 test_loss : 0.19406217370215836
# -------------------------------------------------------------------------------------------------
# epoch : 13/100
# train_loss : 0.005587037108874305 test_loss : 0.19190962283729432
# -------------------------------------------------------------------------------------------------
# epoch : 14/100
# train_loss : 0.005553715860418786 test_loss : 0.19032164340889132
# -------------------------------------------------------------------------------------------------
# epoch : 15/100
# train_loss : 0.005531997060514297 test_loss : 0.18776755404096465
# -------------------------------------------------------------------------------------------------
# epoch : 16/100
# train_loss : 0.005494226462184116 test_loss : 0.1870741750877183
# -------------------------------------------------------------------------------------------------
# epoch : 17/100
# train_loss : 0.005461168093089783 test_loss : 0.18681290376562257
# -------------------------------------------------------------------------------------------------
# epoch : 18/100
# train_loss : 0.005462143792323334 test_loss : 0.1849603535489993
# -------------------------------------------------------------------------------------------------
# epoch : 19/100
# train_loss : 0.005409186597430927 test_loss : 0.18517835619481834
# -------------------------------------------------------------------------------------------------
# epoch : 20/100
# train_loss : 0.005434534810560055 test_loss : 0.18327278643846512
# -------------------------------------------------------------------------------------------------
# epoch : 21/100
# train_loss : 0.005371779142135296 test_loss : 0.1840638341130437
# -------------------------------------------------------------------------------------------------
# epoch : 22/100
# train_loss : 0.005386669400663226 test_loss : 0.18151865208202655
# -------------------------------------------------------------------------------------------------
# epoch : 23/100
# train_loss : 0.005348283090233557 test_loss : 0.18445692667821506
# -------------------------------------------------------------------------------------------------
# epoch : 24/100
# train_loss : 0.005369704515456827 test_loss : 0.1807579124967257
# -------------------------------------------------------------------------------------------------
# epoch : 25/100
# train_loss : 0.005342445874393926 test_loss : 0.1830808247800346
# -------------------------------------------------------------------------------------------------
# epoch : 26/100
# train_loss : 0.005360274398833452 test_loss : 0.17977188822922405
# -------------------------------------------------------------------------------------------------
# epoch : 27/100
# train_loss : 0.005314525301077335 test_loss : 0.18155318176424182
# -------------------------------------------------------------------------------------------------
# epoch : 28/100
# train_loss : 0.005342470079844255 test_loss : 0.17877377643510028
# -------------------------------------------------------------------------------------------------
# epoch : 29/100
# train_loss : 0.005321843573865701 test_loss : 0.18218253700582832
# -------------------------------------------------------------------------------------------------
# epoch : 30/100
# train_loss : 0.005328502620916975 test_loss : 0.17806695428517488
# -------------------------------------------------------------------------------------------------
# epoch : 31/100
# train_loss : 0.005320406362485853 test_loss : 0.18109173012209367
# -------------------------------------------------------------------------------------------------
# epoch : 32/100
# train_loss : 0.005308472855888547 test_loss : 0.17816744791763323
# -------------------------------------------------------------------------------------------------
# epoch : 33/100
# train_loss : 0.005308351537558704 test_loss : 0.17681681532580573
# -------------------------------------------------------------------------------------------------
# epoch : 34/100
# train_loss : 0.005299220235687645 test_loss : 0.17676628743474548
# -------------------------------------------------------------------------------------------------
# epoch : 35/100
# train_loss : 0.005296684714765725 test_loss : 0.1777396229607565
# -------------------------------------------------------------------------------------------------
# epoch : 36/100
# train_loss : 0.00531912223270611 test_loss : 0.17637835214803885
# -------------------------------------------------------------------------------------------------
# epoch : 37/100
# train_loss : 0.005295291374487939 test_loss : 0.17840668666470158
# -------------------------------------------------------------------------------------------------
# epoch : 38/100
# train_loss : 0.005285812423113195 test_loss : 0.17854307088497523
# -------------------------------------------------------------------------------------------------
# epoch : 39/100
# train_loss : 0.0053007238894966545 test_loss : 0.1753685758323283
# -------------------------------------------------------------------------------------------------
# epoch : 40/100
# train_loss : 0.005255680201885388 test_loss : 0.1772124389404649
# -------------------------------------------------------------------------------------------------
# epoch : 41/100
# train_loss : 0.005278245768700666 test_loss : 0.17724314969670665
# -------------------------------------------------------------------------------------------------
# epoch : 42/100
# train_loss : 0.005270594430958432 test_loss : 0.17745288166108433
# -------------------------------------------------------------------------------------------------
# epoch : 43/100
# train_loss : 0.005280080500982493 test_loss : 0.1806772358648412
# -------------------------------------------------------------------------------------------------
# epoch : 44/100
# train_loss : 0.005266206069626655 test_loss : 0.17641577896502642
# -------------------------------------------------------------------------------------------------
# epoch : 45/100
# train_loss : 0.005280645003745293 test_loss : 0.17411792352124378
# -------------------------------------------------------------------------------------------------
# epoch : 46/100
# train_loss : 0.0052359141894527455 test_loss : 0.1755508793232677
# -------------------------------------------------------------------------------------------------
# epoch : 47/100
# train_loss : 0.005251794711337504 test_loss : 0.178882497119474
# -------------------------------------------------------------------------------------------------
# epoch : 48/100
# train_loss : 0.005269945786169247 test_loss : 0.17923523358128093
# -------------------------------------------------------------------------------------------------
# epoch : 49/100
# train_loss : 0.005253471612848591 test_loss : 0.17822472690730481
# -------------------------------------------------------------------------------------------------
# epoch : 50/100
# train_loss : 0.005257230254580829 test_loss : 0.17429764132510434
# -------------------------------------------------------------------------------------------------
# epoch : 51/100
# train_loss : 0.005249382924183825 test_loss : 0.1741109018524488
# -------------------------------------------------------------------------------------------------
# epoch : 52/100
# train_loss : 0.005245154364783932 test_loss : 0.175895063793874
# -------------------------------------------------------------------------------------------------
# epoch : 53/100
# train_loss : 0.005244590050966631 test_loss : 0.17432732618338354
# -------------------------------------------------------------------------------------------------
# epoch : 54/100
# train_loss : 0.005245375987640221 test_loss : 0.17411121397136567
# -------------------------------------------------------------------------------------------------
# epoch : 55/100
# train_loss : 0.005256307051556008 test_loss : 0.17272061478715758
# -------------------------------------------------------------------------------------------------
# epoch : 56/100
# train_loss : 0.005217052689760494 test_loss : 0.17889852439229553
# -------------------------------------------------------------------------------------------------
# epoch : 57/100
# train_loss : 0.005244203759555215 test_loss : 0.17737714442852381
# -------------------------------------------------------------------------------------------------
# epoch : 58/100
# train_loss : 0.0052132240105279915 test_loss : 0.17867061690435754
# -------------------------------------------------------------------------------------------------
# epoch : 59/100
# train_loss : 0.005212916958773275 test_loss : 0.17563522982973237
# -------------------------------------------------------------------------------------------------
# epoch : 60/100
# train_loss : 0.005240302157573621 test_loss : 0.1798475018895424
# -------------------------------------------------------------------------------------------------
# epoch : 61/100
# train_loss : 0.005238441519331981 test_loss : 0.17609689263878642
# -------------------------------------------------------------------------------------------------
# epoch : 62/100
# train_loss : 0.005214307592534463 test_loss : 0.1775152534917668
# -------------------------------------------------------------------------------------------------
# epoch : 63/100
# train_loss : 0.0052370610733077985 test_loss : 0.1735607834683882
# -------------------------------------------------------------------------------------------------
# epoch : 64/100
# train_loss : 0.005283748688887373 test_loss : 0.17480386625807565
# -------------------------------------------------------------------------------------------------
# epoch : 65/100
# train_loss : 0.005270412251751582 test_loss : 0.17358653885018718
# -------------------------------------------------------------------------------------------------
# epoch : 66/100
# train_loss : 0.005246828089967993 test_loss : 0.17380050744290823
# -------------------------------------------------------------------------------------------------
# epoch : 67/100
# train_loss : 0.005219032225786945 test_loss : 0.1779770159103849
# -------------------------------------------------------------------------------------------------
# epoch : 68/100
# train_loss : 0.0051994186259852115 test_loss : 0.17451274737312988
# -------------------------------------------------------------------------------------------------
# epoch : 69/100
# train_loss : 0.005210681268824054 test_loss : 0.17655124595841845
# -------------------------------------------------------------------------------------------------
# epoch : 70/100
# train_loss : 0.005197145310348644 test_loss : 0.17720090208558348
# -------------------------------------------------------------------------------------------------
# epoch : 71/100
# train_loss : 0.005212749016865056 test_loss : 0.18002130326118554
# -------------------------------------------------------------------------------------------------
# epoch : 72/100
# train_loss : 0.005213972101928928 test_loss : 0.1732987086917903
# -------------------------------------------------------------------------------------------------
# epoch : 73/100
# train_loss : 0.005223527223872681 test_loss : 0.1722658007397308
# -------------------------------------------------------------------------------------------------
# epoch : 74/100
# train_loss : 0.00520185298446599 test_loss : 0.17311853620114628
# -------------------------------------------------------------------------------------------------
# epoch : 75/100
# train_loss : 0.005238621906109915 test_loss : 0.1727673710063771
# -------------------------------------------------------------------------------------------------
# epoch : 76/100
# train_loss : 0.005220645963328599 test_loss : 0.17424488154886006
# -------------------------------------------------------------------------------------------------
# epoch : 77/100
# train_loss : 0.005268356034492613 test_loss : 0.17348203539579837
# -------------------------------------------------------------------------------------------------
# epoch : 78/100
# train_loss : 0.005205651585617811 test_loss : 0.17422005406639599
# -------------------------------------------------------------------------------------------------
# epoch : 79/100
# train_loss : 0.00521763669986934 test_loss : 0.1822723924173965
# -------------------------------------------------------------------------------------------------
# epoch : 80/100
# train_loss : 0.005195110699262743 test_loss : 0.17398585681174253
# -------------------------------------------------------------------------------------------------
# epoch : 81/100
# train_loss : 0.0051750163455136925 test_loss : 0.17711001211726987
# -------------------------------------------------------------------------------------------------
# epoch : 82/100
# train_loss : 0.005185820080590133 test_loss : 0.17734716476889345
# -------------------------------------------------------------------------------------------------
# epoch : 83/100
# train_loss : 0.005173060044676903 test_loss : 0.1737168252065375
# -------------------------------------------------------------------------------------------------
# epoch : 84/100
# train_loss : 0.005206765501036719 test_loss : 0.17342067979746037
# -------------------------------------------------------------------------------------------------
# epoch : 85/100
# train_loss : 0.005191954318753165 test_loss : 0.17469560542890616
# -------------------------------------------------------------------------------------------------
# epoch : 86/100
# train_loss : 0.005193706384826148 test_loss : 0.1729043266391969
# -------------------------------------------------------------------------------------------------
# epoch : 87/100
# train_loss : 0.005186165197202814 test_loss : 0.17408680479537259
# -------------------------------------------------------------------------------------------------
# epoch : 88/100
# train_loss : 0.00521934313815779 test_loss : 0.1751616940170795
# -------------------------------------------------------------------------------------------------
# epoch : 89/100
# train_loss : 0.005164547845711032 test_loss : 0.1736038930647008
# -------------------------------------------------------------------------------------------------
# epoch : 90/100
# train_loss : 0.005185366718633441 test_loss : 0.173282601744742
# -------------------------------------------------------------------------------------------------
# epoch : 91/100
# train_loss : 0.005198920218400386 test_loss : 0.17303761873427811
# -------------------------------------------------------------------------------------------------
# epoch : 92/100
# train_loss : 0.005205029112333464 test_loss : 0.17323453610276315
# -------------------------------------------------------------------------------------------------
# epoch : 93/100
# train_loss : 0.005187686591462128 test_loss : 0.17341258349987837
# -------------------------------------------------------------------------------------------------
# epoch : 94/100
# train_loss : 0.0051596145247089446 test_loss : 0.1763310708306931
# -------------------------------------------------------------------------------------------------
# epoch : 95/100
# train_loss : 0.005145994781671606 test_loss : 0.17977203368335157
# -------------------------------------------------------------------------------------------------
# epoch : 96/100
# train_loss : 0.0051818389683001825 test_loss : 0.18278270228220536
# -------------------------------------------------------------------------------------------------
# epoch : 97/100
# train_loss : 0.00521022524631048 test_loss : 0.173744726087059
# -------------------------------------------------------------------------------------------------
# epoch : 98/100
# train_loss : 0.0052109529520241345 test_loss : 0.17375525395880947
# -------------------------------------------------------------------------------------------------
# epoch : 99/100
# train_loss : 0.005211567147453 test_loss : 0.1731487082334252
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Visualisation des performances d'entraînement

# %%
loss = history_train_loss
val_loss = history_test_loss

plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Mean Square Error')

plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## Visualisation des données de test

# %% [markdown]
# **Utilisez** la méthode `forward` pour obtenir les prédictions sur le jeu de données de test.

# %%
for x, y in dataloader_test:
  pred = model.forward(x).detach().numpy()
  break

# %%
plt.figure(figsize=(20,10))
plt.plot(y, color = 'black', label = 'Delhi Mean Temperature')
plt.plot(pred, color = 'green', label = 'Predicted Delhi Mean Temperature')
plt.title('Delhi Mean Temp Prediction')
plt.xlabel('Time')
plt.ylabel('Mean Temp')
plt.legend()
plt.show()
